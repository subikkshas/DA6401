# %% [markdown]
# <a href="https://colab.research.google.com/github/subikkshas/DA6401/blob/main/Q4to6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import fashion_mnist
import numpy as np
from  matplotlib import pyplot as plt
import time
import math
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm

# %%
import wandb
# !wandb login
# Out:
# wandb: Currently logged in as: subikksha (subikksha-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
dataset= fashion_mnist.load_data()
(X_train_and_validation, y_train_and_validation), (X_test, y_test) = dataset
X_train, X_validation, y_train, y_validation = train_test_split(X_train_and_validation, y_train_and_validation, test_size=0.1, random_state=42)
X_train = (X_train/255.0).astype(np.float32)
X_validation = (X_validation/255.0).astype(np.float32)
X_test = (X_test/255.0).astype(np.float32)

print("Train Dataset Shape: ", X_train.shape)
print("Train Target Vector Shape: ", y_train.shape)
print("Test Dataset Shape:", X_test.shape)
print("Test Target Vector Shape", y_test.shape)
print("Validation Dataset Shape:", X_validation.shape)
print("Validation Target Vector Shape", y_validation.shape)
# Out:
# Train Dataset Shape:  (54000, 28, 28)
# Train Target Vector Shape:  (54000,)
# Test Dataset Shape: (10000, 28, 28)
# Test Target Vector Shape (10000,)
# Validation Dataset Shape: (6000, 28, 28)
# Validation Target Vector Shape (6000,)

# %%
X_train = np.array(X_train.reshape(X_train.shape[0], 784,1))
X_test = np.array(X_test.reshape(X_test.shape[0], 784,1))
X_validation = np.array(X_validation.reshape(X_validation.shape[0], 784,1))

# %%
def layer_init(arr,n1,n2,init_type):
    np.random.seed(10)
    if init_type=="random":
        arr.append(np.random.randn(n1,n2)*0.1)
    elif init_type=="xavier":
        arr.append(np.random.randn(n1,n2)*np.sqrt(2/(n1+n2)))
    return arr

def param(layers,init_type):
    W=[]
    B=[]
    for i in range(len(layers)-1):
        W=layer_init(W,layers[i+1],layers[i],init_type)
        B=layer_init(B,layers[i+1],1,init_type)
    return W,B

#Activation function
def activation(activation_function):
    if activation_function == 'sigmoid':
        return sigmoid
    if activation_function == 'tanh':
        return tanh
    if activation_function == 'ReLU':
        return relu

def sigmoid(x, derivative = False):
    if derivative:
        return sigmoid(x)*(1-sigmoid(x))
    return 1/(1 + np.exp(-x))

def tanh(x, derivative = False):
    if derivative:
        return 1 - tanh(x)**2
    return (np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))

def relu(x, derivative = False):
    if derivative:
        return (x>0)*1
    return x*(x>0)

def softmax(x,derivative = False):
    if derivative:
        return softmax(x)*(1- softmax(x))
    return np.exp(x)/np.sum(np.exp(x), axis = 0)

def one_hot(y, num_output_nodes):
    v = np.zeros((num_output_nodes, len(y)))
    for i,j in enumerate(y):
        v[j,i] = 1
    return v


def forward(x, W, B, activation_type):
    h = []
    a = []
    sigma = activation(activation_type)  #activation
    h.append(x)   #h0 = x
    a.append(np.dot(W[0], h[0]) + B[0])
    for i in range(len(W)-1):
        h.append(sigma(a[-1]))
        a.append(np.dot(W[i+1], h[-1]) + B[i+1])
    y_hat = softmax(a[-1])

    return y_hat, h, a



def loss(y,y_hat,l_type,W,reg,n_class):
    if l_type=='cross_entropy':
        err=-1*np.sum(np.multiply(one_hot(y,n_class),np.log(y_hat)))/one_hot(y,n_class).shape[1]
    elif l_type=='squared_error':
        err=np.sum((one_hot(y,n_class)-y_hat)**2)/(2*one_hot(y,n_class)).shape[1]

    if W:
        r=0
        for i in range(len(W)):
            r+=np.sum((np.array(W,dtype=object)**2)[i])
        err=err+reg*r
    return err

def eval_acc(y_hat, y_true):
    return np.mean(np.argmax(y_hat, axis = 0) ==y_true )*100

# %%
def back_prop(x, y, y_hat, a, h , W, B, batch_size,l_type,act_type):
    grad_h,grad_a,grad_W,grad_B = [0]*len(h),[0]*len(a),[0]*len(W),[0]*len(B)
    sigma = activation(act_type)

    if l_type == "cross_entropy":
        grad_h[-1] = -1*(y/y_hat)
        grad_a[-1] = -1*(y-y_hat)
    if l_type == "squared_error":   ##### edit this
        grad_h[-1] = y_hat - y
        grad_a[-1] = (y_hat - y)*softmax(a[-1])*(1-softmax(a[-1]))

    for i in range(len(W)-1, -1, -1):
        grad_W[i] = np.dot(grad_a[i], h[i].T)
        grad_B[i] = np.dot(grad_a[i], np.ones((grad_a[i].shape[1], 1)))
        if i > 0:
            grad_h[i-1] = np.dot(W[i].T, grad_a[i])
            grad_a[i-1]  = np.multiply(grad_h[i-1],sigma(a[i-1], derivative = True))

    return grad_W, grad_B, grad_h, grad_a

# %%
def sgd_step(W,B,grad_W,grad_B,lr,reg):
    W=np.array(W,dtype=object)
    B=np.array(B,dtype=object)
    W-=lr*reg*W+lr*np.array(grad_W,dtype=object)
    B-=lr*reg*B+lr*np.array(grad_B,dtype=object)

    return W.tolist(),B.tolist()



def momentum_step(w, b, gW, gB, lr=0.001, gamma=0.9, reg=0):
    params = {'w': w, 'b': b}

    Wmoments = [np.zeros_like(p) for p in params['w']]
    Bmoments = [np.zeros_like(p) for p in params['b']]

    Wmoments = gamma * np.array(Wmoments,dtype=object) + lr * np.array(gW,dtype=object)
    W = (1 - lr * reg) * np.array(params['w'],dtype=object) - Wmoments
    Wmoments = Wmoments.tolist()

    Bmoments = gamma * np.array(Bmoments,dtype=object) + lr * np.array(gB,dtype=object)
    B = (1 - lr * reg) * np.array(params['b'],dtype=object) - Bmoments
    Bmoments = Bmoments.tolist()

    return W.tolist(), B.tolist()


def RMSprop_step(w, b, gW, gB, lr=0.01, beta=0.99):
    params = {'w': w, 'b': b}

    vW = [np.zeros_like(p) for p in params['w']]
    vB = [np.zeros_like(p) for p in params['b']]

    vW = beta * np.array(vW, dtype=object) + (1 - beta) * (np.array(gW, dtype=object) ** 2)
    W = np.array(params['w'], dtype=object) - (lr / ((vW + 1e-7) ** 0.5)) * np.array(gW, dtype=object)

    vB = beta * np.array(vB, dtype=object) + (1 - beta) * (np.array(gB, dtype=object) ** 2)
    B = np.array(params['b'], dtype=object) - (lr / ((vB + 1e-7) ** 0.5)) * np.array(gB, dtype=object)

    return W.tolist(), B.tolist()

# %%
import wandb

def train(X_train, y_train, x_val, y_val, num_inputs_nodes, hidden_layers, out_num, init_type, epochs,
          batch_size, l_type, act_type, op_name, lr_rate, reg):

    # Ensure WandB starts fresh
    wandb.finish()

    run = wandb.init(project="DA6401-Assignment-1", name="training-run", reinit=True)

    in_node = [num_inputs_nodes]
    layers = []
    layers.extend(in_node)
    layers.extend(hidden_layers)
    layers.extend([out_num])

    W, B = param(layers, init_type)
    N = X_train.shape[0]
    n_batches = int(np.floor(N / batch_size))

    for epoch in range(epochs):
        train_loss, train_accuracy, val_loss, val_accuracy = [], [], [], []
        l, acc, ds, steps = 0, 0, 0, 1

        while ds < N:
            mini_batch_size = min((N - ds), batch_size)
            x = np.squeeze(X_train[ds:ds + mini_batch_size]).T
            y = one_hot(y_train[ds:ds + mini_batch_size], out_num)

            y_hat, h, a = forward(x, W, B, act_type)
            grad_W, grad_B, grad_h, grad_a = back_prop(x, y, y_hat, a, h, W, B, batch_size, l_type, act_type)

            if op_name == 'sgd':
                W, B = sgd_step(W, B, grad_W, grad_B, lr_rate, reg)
            elif op_name == 'momentum':
                W, B = momentum_step(W, B, grad_W, grad_B, lr_rate, reg)
            elif op_name == 'rmsprop':
                W, B = RMSprop_step(W, B, grad_W, grad_B, lr_rate, reg)

            l += loss(y_train[ds:ds + mini_batch_size], y_hat, l_type, W, reg, out_num)
            acc += eval_acc(y_hat, y_train[ds:ds + mini_batch_size])

            steps += 1
            ds += batch_size

        l /= (n_batches + mini_batch_size)
        acc /= steps

        train_loss.append(l)
        train_accuracy.append(acc)

        y_val_hat, _, _ = forward(np.squeeze(x_val).T, W, B, act_type)
        val_acc = eval_acc(y_val_hat, y_val)
        val_l = loss(y_val, y_val_hat, l_type, W=None, reg=reg, n_class=out_num)

        val_accuracy.append(val_acc)
        val_loss.append(val_l)

        wandb.log({"epoch": epoch, "Train_loss": l, "Train_acc": acc, "val_loss": val_l, "val_Accuracy": val_acc})

        #print(f"Epoch {epoch}: Train Loss = {l:.4f}, Train Accuracy = {acc:.4f}, Val Loss = {val_l:.4f}, Val Accuracy = {val_acc:.4f}")

    wandb.finish()  # Explicitly finish the WandB run

    return W, B, train_loss, train_accuracy, val_loss, val_accuracy

# %%
hidden_layers=[64,32,16]
init_type='random'
epochs=10
batch_size=50
loss_type='squared_error'
optimizer_name='rmsprop'
learning_rate=1e-3
reg_lamda=0
activation_type='sigmoid'

# %%
wandb.init(project="DA6401-Assignment-1")
fit=train(X_train, y_train, X_validation, y_validation,784,hidden_layers, 10, init_type, epochs, batch_size,
                                                                 loss_type, activation_type, optimizer_name, learning_rate,
                                                                 reg_lamda)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: subikksha (subikksha-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093242-hs0esmuo</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/hs0esmuo' target="_blank">vague-music-574</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/hs0esmuo' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/hs0esmuo</a>
#  View run <strong style="color:#cdcd00">vague-music-574</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/hs0esmuo' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/hs0esmuo</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093242-hs0esmuo/logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093246-g0lco4lt</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/g0lco4lt' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/g0lco4lt' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/g0lco4lt</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▅▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>84.07956</td></tr><tr><td>Train_loss</td><td>0.2313</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>83.65</td></tr><tr><td>val_loss</td><td>0.24556</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/g0lco4lt' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/g0lco4lt</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093246-g0lco4lt/logs</code>

# %%
import wandb

# %%
sweep_configuration = {'method'    : "random",  #Other available--> grid, bayes
                       'metric'    : {'name': 'val_Accuracy','goal':'maximize'},
                       'parameters': {'epochs':{'values':[ 5, 10]},
                                      'hidden_layers':{'values':[[64,32],[64,32,16],[128,64,32],[128,64,32,16],[128,32,32,16]] }, #change needed
                                      'learning_rate':{'values':[1e-3,1e-4]},
                                      'weight_decay':{'values':[0, 0.0005, 0.5]},
                                      'optimizer_name': {'values':['sgd', 'momentum', 'rmsprop', 'nesterov','adam']}, #, 'nesterov','adam', 'nadam'
                                      'batch_size':{'values':[16,32,64]},
                                      'init_type': {'values':['random','xavier']},
                                      'activation_type':{'values':['sigmoid','tanh','ReLU']},
                                      'loss_type': {'values':['cross_entropy']} }}

# %%
def sweep_train():
    hyperparameters = dict(epochs=5,
                           hidden_layers=[64, 32],
                           learning_rate=1e-4,
                           weight_decay=0,
                           optimizer_name='sgd',
                           batch_size=16,
                           init_type='random',
                           activation_type='sigmoid',
                           loss_type='cross_entropy',
                           reg_lamda=0)

    wandb.init(project="DA6401-Assignment-1", entity="subikksha", config=hyperparameters)
    config = wandb.config
    epochs = config.epochs
    hidden_layers = config.hidden_layers
    learning_rate = config.learning_rate
    weight_decay = config.weight_decay
    optimizer_name = config.optimizer_name
    batch_size = config.batch_size
    init_type = config.init_type
    activation_type = config.activation_type
    loss_type = config.loss_type
    reg_lamda = config.reg_lamda
    wandb.run.name = "e_{}_hl_{}_lr_{}_wd_{}_o_{}_bs_{}_winit_{}_ac_{}_los_{}_r_{}".format(epochs, \
                                                                                           hidden_layers, \
                                                                                           learning_rate, \
                                                                                           weight_decay, \
                                                                                           optimizer_name, \
                                                                                           batch_size, \
                                                                                           init_type, \
                                                                                           activation_type, \
                                                                                           loss_type, \
                                                                                           reg_lamda)

    _, _, train_loss, train_accuracy, val_loss, val_accuracy = train(X_train, y_train, X_validation, y_validation, 784,
                                                                     hidden_layers, 10, init_type, epochs, batch_size,
                                                                     loss_type, activation_type, optimizer_name,
                                                                     learning_rate, reg_lamda)

# %%
import wandb

def sweep_train():
    wandb.finish()  # Ensure no previous session is hanging

    hyperparameters = dict(
        epochs=5,
        hidden_layers=[128, 64, 32],
        learning_rate=1e-3,
        weight_decay=0.0005,
        optimizer_name='nesterov',
        batch_size=32,
        init_type='xavier',
        activation_type='ReLU',
        loss_type='cross_entropy',
        reg_lamda=0
    )

    run = wandb.init(project="DA6401-Assignment-1", config=hyperparameters)

    config = wandb.config
    wandb.run.name = f"hl_{len(config.hidden_layers)}_bs_{config.batch_size}_ac_{config.activation_type}"

    _, _, train_loss, train_accuracy, val_loss, val_accuracy = train(
        X_train, y_train, X_validation, y_validation, 784,
        config.hidden_layers, 10, config.init_type, config.epochs, config.batch_size,
        config.loss_type, config.activation_type, config.optimizer_name,
        config.learning_rate, config.reg_lamda
    )

    wandb.finish()

# %%
sweep_id = wandb.sweep(sweep_configuration,project="DA6401-Assignment-1")
wandb.agent(sweep_id,function=sweep_train,project="DA6401-Assignment-1",count=100)
# Out:
# Create sweep with ID: rzaqqqtp
# Sweep URL: https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp
# wandb: Agent Starting Run: iis6e49w with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093335-iis6e49w</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">hearty-sweep-1</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w</a>
#  View run <strong style="color:#cdcd00">hl_4_bs_32_ac_sigmoid</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093335-iis6e49w/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093338-iis6e49w</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>10.00037</td></tr><tr><td>Train_loss</td><td>2.43545</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>9.95</td></tr><tr><td>val_loss</td><td>2.46971</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/iis6e49w</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093338-iis6e49w/logs</code>
# wandb: Agent Starting Run: tlo3abpm with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 32, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: nesterov
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093416-tlo3abpm</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">jolly-sweep-2</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm</a>
#  View run <strong style="color:#cdcd00">hl_4_bs_64_ac_tanh</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093416-tlo3abpm/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093419-tlo3abpm</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>11.57359</td></tr><tr><td>Train_loss</td><td>2.17743</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>11.61667</td></tr><tr><td>val_loss</td><td>2.29914</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/tlo3abpm</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093419-tlo3abpm/logs</code>
# wandb: Agent Starting Run: r7zitqzh with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093523-r7zitqzh</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">logical-sweep-3</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_64_ac_sigmoid</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093523-r7zitqzh/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093526-r7zitqzh</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▃▁▂▂▃▄▅▆▇█</td></tr><tr><td>Train_loss</td><td>█▄▄▃▃▂▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▇▁▅▆▇█████</td></tr><tr><td>val_loss</td><td>█▇▆▅▅▄▃▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>11.90274</td></tr><tr><td>Train_loss</td><td>2.18018</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>10.33333</td></tr><tr><td>val_loss</td><td>2.30131</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/r7zitqzh</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093526-r7zitqzh/logs</code>
# wandb: Agent Starting Run: koeoxxri with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093601-koeoxxri</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">quiet-sweep-4</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_16_ac_tanh</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093601-koeoxxri/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093604-koeoxxri</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▇▇▇████</td></tr><tr><td>Train_loss</td><td>█▁▂▁▂▃▄▅▅▅</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▅▆▆▆██▇▆</td></tr><tr><td>val_loss</td><td>▂▁▁▃▅▇▄▅██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>85.79495</td></tr><tr><td>Train_loss</td><td>0.53149</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>84.83333</td></tr><tr><td>val_loss</td><td>0.57407</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/koeoxxri</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093604-koeoxxri/logs</code>
# wandb: Agent Starting Run: zdsmzd16 with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093902-zdsmzd16</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">dainty-sweep-5</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_16_ac_ReLU</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093902-zdsmzd16/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_093905-zdsmzd16</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇▇▇▇████</td></tr><tr><td>Train_loss</td><td>█▃▃▂▂▂▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▆▆▇█████</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>88.40529</td></tr><tr><td>Train_loss</td><td>0.31679</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>86.75</td></tr><tr><td>val_loss</td><td>0.37853</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/zdsmzd16</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_093905-zdsmzd16/logs</code>
# wandb: Agent Starting Run: miq8e0s3 with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094014-miq8e0s3</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">fragrant-sweep-6</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_ac_sigmoid</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094014-miq8e0s3/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094017-miq8e0s3</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▃▅▆▆▇▇███</td></tr><tr><td>Train_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▄▅▆▇▇███</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>79.81794</td></tr><tr><td>Train_loss</td><td>0.59958</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>79.85</td></tr><tr><td>val_loss</td><td>0.59721</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/miq8e0s3</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094017-miq8e0s3/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: f5j8xm4v with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: nesterov
# wandb: 	weight_decay: 0.5
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094209-f5j8xm4v</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">pleasant-sweep-7</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_ac_sigmoid</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094209-f5j8xm4v/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094212-f5j8xm4v</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>10.00037</td></tr><tr><td>Train_loss</td><td>2.44052</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>9.95</td></tr><tr><td>val_loss</td><td>2.47489</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/f5j8xm4v</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094212-f5j8xm4v/logs</code>
# wandb: Agent Starting Run: 8pmnel5f with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094235-8pmnel5f</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">apricot-sweep-8</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f</a>
#  View run <strong style="color:#cdcd00">hl_2_bs_16_ac_sigmoid</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094235-8pmnel5f/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094238-8pmnel5f</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇▇▇█████</td></tr><tr><td>Train_loss</td><td>▇▁▂▃▄▅▅▆▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▄▅▆▆▇▇▇█</td></tr><tr><td>val_loss</td><td>▁▁▂▃▅▅▆▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>85.17847</td></tr><tr><td>Train_loss</td><td>0.75381</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>85.26667</td></tr><tr><td>val_loss</td><td>0.77393</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/8pmnel5f</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_094238-8pmnel5f/logs</code>
# wandb: Agent Starting Run: 1xhqdf84 with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_094409-1xhqdf84</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1xhqdf84' target="_blank">rich-sweep-9</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
# ...
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih</a>
#  View run <strong style="color:#cdcd00">hl_2_bs_16_ac_ReLU</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_112726-b8o3kwih/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_112734-b8o3kwih</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇▇▇█████</td></tr><tr><td>Train_loss</td><td>█▁▁▂▃▃▄▅▅▆</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▅▅▆▆▇▇███</td></tr><tr><td>val_loss</td><td>▂▁▂▃▄▅▅▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>84.43054</td></tr><tr><td>Train_loss</td><td>0.73137</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>83.93333</td></tr><tr><td>val_loss</td><td>0.78327</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/b8o3kwih</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_112734-b8o3kwih/logs</code>
# wandb: Agent Starting Run: 1i154ash with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_112910-1i154ash</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">dainty-sweep-99</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_ac_tanh</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_112910-1i154ash/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_112918-1i154ash</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>7.06224</td></tr><tr><td>Train_loss</td><td>2.83865</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>6.76667</td></tr><tr><td>val_loss</td><td>2.85756</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/1i154ash</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_112918-1i154ash/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: mhwejke0 with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: momentum
# wandb: 	weight_decay: 0.0005
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_113018-mhwejke0</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">cosmic-sweep-100</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0</a>
#  View run <strong style="color:#cdcd00">hl_3_bs_32_ac_tanh</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_113018-mhwejke0/logs</code>
# Ignoring project 'DA6401-Assignment-1' when running a sweep.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_113026-mhwejke0</code>
# Syncing run <strong><a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">training-run</a></strong> to <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View project at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a>
#  View sweep at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/sweeps/rzaqqqtp</a>
#  View run at <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▅▆▆▇████</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>89.6888</td></tr><tr><td>Train_loss</td><td>0.28365</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>87.83333</td></tr><tr><td>val_loss</td><td>0.33159</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">training-run</strong> at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1/runs/mhwejke0</a><br> View project at: <a href='https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1' target="_blank">https://wandb.ai/subikksha-indian-institute-of-technology-madras/DA6401-Assignment-1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250313_113026-mhwejke0/logs</code>
